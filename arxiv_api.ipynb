# %%
# !pip install arxiv
# Out:
# Collecting arxiv
#   Downloading arxiv-0.5.3-py3-none-any.whl (7.0 kB)
# Collecting feedparser
#   Downloading feedparser-5.2.1.tar.bz2 (192 kB)
# Requirement already satisfied: requests in c:\users\jiteshnemade\anaconda3\lib\site-packages (from arxiv) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jiteshnemade\anaconda3\lib\site-packages (from requests->arxiv) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jiteshnemade\anaconda3\lib\site-packages (from requests->arxiv) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jiteshnemade\anaconda3\lib\site-packages (from requests->arxiv) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jiteshnemade\anaconda3\lib\site-packages (from requests->arxiv) (2.8)
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py): started
#   Building wheel for feedparser (setup.py): finished with status 'done'
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44943 sha256=7678c8cced7f0fc4246780f2042445c453b647ead7ac54e543d744cd3859d638
#   Stored in directory: c:\users\jiteshnemade\appdata\local\pip\cache\wheels\4a\87\a9\ef99b7b68f9816d5ef1262dc11ce31a93a844eb69e68c1a031
# Successfully built feedparser
# Installing collected packages: feedparser, arxiv
# Successfully installed arxiv-0.5.3 feedparser-5.2.1
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import arxiv

# Keyword queries
arxiv.query(query="quantum", max_results=100)

# Multi-field queries
arxiv.query(query="au:balents_leon AND cat:cond-mat.str-el")

# Get single record by ID
arxiv.query(id_list=["1707.08567"])

# Get multiple records by ID
arxiv.query(id_list=["1707.08567", "1707.08567"])

# Get an interator over query results
result = arxiv.query(
  query="quantum",
  max_chunk_results=10,
  max_results=100,
  iterative=True
)

for paper in result():
   print(paper)
# Out:
# {'id': 'http://arxiv.org/abs/quant-ph/0201082v1', 'guidislink': True, 'updated': '2002-01-18T15:08:05Z', 'updated_parsed': time.struct_time(tm_year=2002, tm_mon=1, tm_mday=18, tm_hour=15, tm_min=8, tm_sec=5, tm_wday=4, tm_yday=18, tm_isdst=0), 'published': '2002-01-18T15:08:05Z', 'published_parsed': time.struct_time(tm_year=2002, tm_mon=1, tm_mday=18, tm_hour=15, tm_min=8, tm_sec=5, tm_wday=4, tm_yday=18, tm_isdst=0), 'title': 'Quantum Computers and Quantum Computer Languages: Quantum Assembly\n  Language and Quantum C Language', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Computers and Quantum Computer Languages: Quantum Assembly\n  Language and Quantum C Language'}, 'summary': 'We show a representation of Quantum Computers defines Quantum Turing Machines\nwith associated Quantum Grammars. We then create examples of Quantum Grammars.\nLastly we develop an algebraic approach to high level Quantum Languages using\nQuantum Assembly language and Quantum C language as examples.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We show a representation of Quantum Computers defines Quantum Turing Machines\nwith associated Quantum Grammars. We then create examples of Quantum Grammars.\nLastly we develop an algebraic approach to high level Quantum Languages using\nQuantum Assembly language and Quantum C language as examples.'}, 'authors': ['Stephen Blaha'], 'author_detail': {'name': 'Stephen Blaha'}, 'author': 'Stephen Blaha', 'arxiv_comment': '32 pages', 'links': [{'href': 'http://arxiv.org/abs/quant-ph/0201082v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0201082v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'cs.PL', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0201082v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0201082v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/quant-ph/0407102v1', 'guidislink': True, 'updated': '2004-07-14T14:47:27Z', 'updated_parsed': time.struct_time(tm_year=2004, tm_mon=7, tm_mday=14, tm_hour=14, tm_min=47, tm_sec=27, tm_wday=2, tm_yday=196, tm_isdst=0), 'published': '2004-07-14T14:47:27Z', 'published_parsed': time.struct_time(tm_year=2004, tm_mon=7, tm_mday=14, tm_hour=14, tm_min=47, tm_sec=27, tm_wday=2, tm_yday=196, tm_isdst=0), 'title': 'Quantum Networks for Generating Arbitrary Quantum States', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Networks for Generating Arbitrary Quantum States'}, 'summary': 'Quantum protocols often require the generation of specific quantum states. We\ndescribe a quantum algorithm for generating any prescribed quantum state. For\nan important subclass of states, including pure symmetric states, this\nalgorithm is efficient.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum protocols often require the generation of specific quantum states. We\ndescribe a quantum algorithm for generating any prescribed quantum state. For\nan important subclass of states, including pure symmetric states, this\nalgorithm is efficient.'}, 'authors': ['Phillip Kaye', 'Michele Mosca'], 'author_detail': {'name': 'Michele Mosca'}, 'author': 'Michele Mosca', 'arxiv_comment': '3 pages, 2 figures. This paper previously appeared in: Proceedings,\n  International Conference on Quantum Information (ICQI). Rochester, New York,\n  USA, 2001', 'links': [{'href': 'http://arxiv.org/abs/quant-ph/0407102v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0407102v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0407102v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0407102v1', 'journal_reference': 'Phillip Kaye, Michele Mosca, "Quantum Networks for Generating\n  Arbitrary Quantum States", Proceedings, International Conference on Quantum\n  Information (ICQI). Rochester, New York, USA, 2001', 'doi': None}
# {'id': 'http://arxiv.org/abs/0804.3401v1', 'guidislink': True, 'updated': '2008-04-21T20:07:38Z', 'updated_parsed': time.struct_time(tm_year=2008, tm_mon=4, tm_mday=21, tm_hour=20, tm_min=7, tm_sec=38, tm_wday=0, tm_yday=112, tm_isdst=0), 'published': '2008-04-21T20:07:38Z', 'published_parsed': time.struct_time(tm_year=2008, tm_mon=4, tm_mday=21, tm_hour=20, tm_min=7, tm_sec=38, tm_wday=0, tm_yday=112, tm_isdst=0), 'title': 'Quantum Computational Complexity', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Computational Complexity'}, 'summary': 'This article surveys quantum computational complexity, with a focus on three\nfundamental notions: polynomial-time quantum computations, the efficient\nverification of quantum proofs, and quantum interactive proof systems.\nProperties of quantum complexity classes based on these notions, such as BQP,\nQMA, and QIP, are presented. Other topics in quantum complexity, including\nquantum advice, space-bounded quantum computation, and bounded-depth quantum\ncircuits, are also discussed.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'This article surveys quantum computational complexity, with a focus on three\nfundamental notions: polynomial-time quantum computations, the efficient\nverification of quantum proofs, and quantum interactive proof systems.\nProperties of quantum complexity classes based on these notions, such as BQP,\nQMA, and QIP, are presented. Other topics in quantum complexity, including\nquantum advice, space-bounded quantum computation, and bounded-depth quantum\ncircuits, are also discussed.'}, 'authors': ['John Watrous'], 'author_detail': {'name': 'John Watrous'}, 'author': 'John Watrous', 'arxiv_comment': '44 pages, 14 figures. To appear in the Springer Encyclopedia of\n  Complexity and Systems Science', 'links': [{'href': 'http://arxiv.org/abs/0804.3401v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/0804.3401v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/0804.3401v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/0804.3401v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1311.4939v1', 'guidislink': True, 'updated': '2013-11-20T02:23:12Z', 'updated_parsed': time.struct_time(tm_year=2013, tm_mon=11, tm_mday=20, tm_hour=2, tm_min=23, tm_sec=12, tm_wday=2, tm_yday=324, tm_isdst=0), 'published': '2013-11-20T02:23:12Z', 'published_parsed': time.struct_time(tm_year=2013, tm_mon=11, tm_mday=20, tm_hour=2, tm_min=23, tm_sec=12, tm_wday=2, tm_yday=324, tm_isdst=0), 'title': 'Geometrical perspective on quantum states and quantum computation', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Geometrical perspective on quantum states and quantum computation'}, 'summary': "We interpret quantum computing as a geometric evolution process by\nreformulating finite quantum systems via Connes' noncommutative geometry. In\nthis formulation, quantum states are represented as noncommutative connections,\nwhile gauge transformations on the connections play a role of unitary quantum\noperations. Thereby, a geometrical model for quantum computation is presented,\nwhich is equivalent to the quantum circuit model. This result shows a geometric\nway of realizing quantum computing and as such, provides an alternative\nproposal of building a quantum computer.", 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': "We interpret quantum computing as a geometric evolution process by\nreformulating finite quantum systems via Connes' noncommutative geometry. In\nthis formulation, quantum states are represented as noncommutative connections,\nwhile gauge transformations on the connections play a role of unitary quantum\noperations. Thereby, a geometrical model for quantum computation is presented,\nwhich is equivalent to the quantum circuit model. This result shows a geometric\nway of realizing quantum computing and as such, provides an alternative\nproposal of building a quantum computer."}, 'authors': ['Zeqian Chen'], 'author_detail': {'name': 'Zeqian Chen'}, 'author': 'Zeqian Chen', 'arxiv_comment': '4 pages', 'links': [{'href': 'http://arxiv.org/abs/1311.4939v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1311.4939v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1311.4939v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1311.4939v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1611.03472v1', 'guidislink': True, 'updated': '2016-11-10T20:30:19Z', 'updated_parsed': time.struct_time(tm_year=2016, tm_mon=11, tm_mday=10, tm_hour=20, tm_min=30, tm_sec=19, tm_wday=3, tm_yday=315, tm_isdst=0), 'published': '2016-11-10T20:30:19Z', 'published_parsed': time.struct_time(tm_year=2016, tm_mon=11, tm_mday=10, tm_hour=20, tm_min=30, tm_sec=19, tm_wday=3, tm_yday=315, tm_isdst=0), 'title': 'Universal Quantum Algorithm', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Universal Quantum Algorithm'}, 'summary': 'Quantum amplitude amplification and quantum phase estimation are two\nfundamental quantum algorithms. All known quantum algorithms are derived from\nthese two algorithms. Even the adiabatic quantum algorithms can also be\nefficiently simulated using quantum phase estimation. We present a universal\nquantum algorithm which explains these two algorithms as special cases. An\ninteresting result is that we do not need quantum fourier transform to do\nquantum phase estimation.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum amplitude amplification and quantum phase estimation are two\nfundamental quantum algorithms. All known quantum algorithms are derived from\nthese two algorithms. Even the adiabatic quantum algorithms can also be\nefficiently simulated using quantum phase estimation. We present a universal\nquantum algorithm which explains these two algorithms as special cases. An\ninteresting result is that we do not need quantum fourier transform to do\nquantum phase estimation.'}, 'authors': ['Avatar Tulsi'], 'author_detail': {'name': 'Avatar Tulsi'}, 'author': 'Avatar Tulsi', 'arxiv_comment': 'This is a preliminary draft. Comments are most welcome', 'links': [{'href': 'http://arxiv.org/abs/1611.03472v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1611.03472v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1611.03472v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1611.03472v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/q-alg/9610034v1', 'guidislink': True, 'updated': '1996-10-30T15:57:00Z', 'updated_parsed': time.struct_time(tm_year=1996, tm_mon=10, tm_mday=30, tm_hour=15, tm_min=57, tm_sec=0, tm_wday=2, tm_yday=304, tm_isdst=0), 'published': '1996-10-30T15:57:00Z', 'published_parsed': time.struct_time(tm_year=1996, tm_mon=10, tm_mday=30, tm_hour=15, tm_min=57, tm_sec=0, tm_wday=2, tm_yday=304, tm_isdst=0), 'title': 'Quantum Grothendieck polynomials', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Grothendieck polynomials'}, 'summary': 'We study the algebraic aspects of (small) quantum equivariant $K$-theory of\nflag manifold. Lascoux-Sch\\"utzenberger\'s type formula for quantum double and\nquantum double dual Grothendieck polynomials and the quantum Cauchy identity\nfor quantum Grothendieck polynomials are obtained.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We study the algebraic aspects of (small) quantum equivariant $K$-theory of\nflag manifold. Lascoux-Sch\\"utzenberger\'s type formula for quantum double and\nquantum double dual Grothendieck polynomials and the quantum Cauchy identity\nfor quantum Grothendieck polynomials are obtained.'}, 'authors': ['Anatol N. Kirillov'], 'author_detail': {'name': 'Anatol N. Kirillov'}, 'author': 'Anatol N. Kirillov', 'arxiv_comment': 'PlainTeX, 13 pages', 'links': [{'href': 'http://arxiv.org/abs/q-alg/9610034v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/q-alg/9610034v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'q-alg', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'q-alg', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'math.QA', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/q-alg/9610034v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/q-alg/9610034v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/quant-ph/0302169v1', 'guidislink': True, 'updated': '2003-02-21T20:20:47Z', 'updated_parsed': time.struct_time(tm_year=2003, tm_mon=2, tm_mday=21, tm_hour=20, tm_min=20, tm_sec=47, tm_wday=4, tm_yday=52, tm_isdst=0), 'published': '2003-02-21T20:20:47Z', 'published_parsed': time.struct_time(tm_year=2003, tm_mon=2, tm_mday=21, tm_hour=20, tm_min=20, tm_sec=47, tm_wday=4, tm_yday=52, tm_isdst=0), 'title': 'Nonlinear Dynamics In Quantum Physics -- Quantum Chaos and Quantum\n  Instantons', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Nonlinear Dynamics In Quantum Physics -- Quantum Chaos and Quantum\n  Instantons'}, 'summary': 'We discuss the recently proposed quantum action - its interpretation, its\nmotivation, its mathematical properties and its use in physics: quantum\nmechanical tunneling, quantum instantons and quantum chaos.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We discuss the recently proposed quantum action - its interpretation, its\nmotivation, its mathematical properties and its use in physics: quantum\nmechanical tunneling, quantum instantons and quantum chaos.'}, 'authors': ['H. Kröger'], 'author_detail': {'name': 'H. Kröger'}, 'author': 'H. Kröger', 'arxiv_comment': 'inv. talk, 10th Int. Conf. Comput. and Appl. Math., Leuven, Belgium\n  (2002)', 'links': [{'href': 'http://arxiv.org/abs/quant-ph/0302169v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0302169v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0302169v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0302169v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/quant-ph/0309066v1', 'guidislink': True, 'updated': '2003-09-08T09:37:27Z', 'updated_parsed': time.struct_time(tm_year=2003, tm_mon=9, tm_mday=8, tm_hour=9, tm_min=37, tm_sec=27, tm_wday=0, tm_yday=251, tm_isdst=0), 'published': '2003-09-08T09:37:27Z', 'published_parsed': time.struct_time(tm_year=2003, tm_mon=9, tm_mday=8, tm_hour=9, tm_min=37, tm_sec=27, tm_wday=0, tm_yday=251, tm_isdst=0), 'title': 'Probabilistic foundations of quantum mechanics and quantum information', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Probabilistic foundations of quantum mechanics and quantum information'}, 'summary': 'We discuss foundation of quantum mechanics (interpretations, superposition,\nprinciple of complementarity, locality, hidden variables) and quantum\ninformation theory.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We discuss foundation of quantum mechanics (interpretations, superposition,\nprinciple of complementarity, locality, hidden variables) and quantum\ninformation theory.'}, 'authors': ['Andrei Khrennikov'], 'author_detail': {'name': 'Andrei Khrennikov'}, 'author': 'Andrei Khrennikov', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1117/12.517850', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/quant-ph/0309066v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0309066v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_comment': 'Contextual probabilistic viewpoint to quantum cryptography project', 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0309066v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0309066v1', 'journal_reference': None, 'doi': '10.1117/12.517850'}
# {'id': 'http://arxiv.org/abs/quant-ph/0504224v1', 'guidislink': True, 'updated': '2005-04-29T09:41:00Z', 'updated_parsed': time.struct_time(tm_year=2005, tm_mon=4, tm_mday=29, tm_hour=9, tm_min=41, tm_sec=0, tm_wday=4, tm_yday=119, tm_isdst=0), 'published': '2005-04-29T09:41:00Z', 'published_parsed': time.struct_time(tm_year=2005, tm_mon=4, tm_mday=29, tm_hour=9, tm_min=41, tm_sec=0, tm_wday=4, tm_yday=119, tm_isdst=0), 'title': 'From quantum graphs to quantum random walks', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'From quantum graphs to quantum random walks'}, 'summary': 'We give a short overview over recent developments on quantum graphs and\noutline the connection between general quantum graphs and so-called quantum\nrandom walks.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We give a short overview over recent developments on quantum graphs and\noutline the connection between general quantum graphs and so-called quantum\nrandom walks.'}, 'authors': ['Gregor Tanner'], 'author_detail': {'name': 'Gregor Tanner'}, 'author': 'Gregor Tanner', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1007/1-4020-3949-2_6', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/quant-ph/0504224v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0504224v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_comment': '14 pages, 6 figures', 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0504224v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0504224v1', 'journal_reference': None, 'doi': '10.1007/1-4020-3949-2_6'}
# {'id': 'http://arxiv.org/abs/1610.02500v1', 'guidislink': True, 'updated': '2016-10-08T08:48:09Z', 'updated_parsed': time.struct_time(tm_year=2016, tm_mon=10, tm_mday=8, tm_hour=8, tm_min=48, tm_sec=9, tm_wday=5, tm_yday=282, tm_isdst=0), 'published': '2016-10-08T08:48:09Z', 'published_parsed': time.struct_time(tm_year=2016, tm_mon=10, tm_mday=8, tm_hour=8, tm_min=48, tm_sec=9, tm_wday=5, tm_yday=282, tm_isdst=0), 'title': 'Probabilistic Process Algebra to Unifying Quantum and Classical\n  Computing in Closed Systems', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Probabilistic Process Algebra to Unifying Quantum and Classical\n  Computing in Closed Systems'}, 'summary': 'We have unified quantum and classical computing in open quantum systems\ncalled qACP which is a quantum generalization of process algebra ACP. But, an\naxiomatization for quantum and classical processes with an assumption of closed\nquantum systems is still missing. For closed quantum systems, unitary operator,\nquantum measurement and quantum entanglement are three basic components for\nquantum computing. This leads to probability unavoidable. Along the solution of\nqACP to unify quantum and classical computing in open quantum systems, we unify\nquantum and classical computing with an assumption of closed systems under the\nframework of ACP-like probabilistic process algebra. This unification make it\ncan be used widely in verification for quantum and classical computing mixed\nsystems, such as most quantum communication protocols.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=0&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We have unified quantum and classical computing in open quantum systems\ncalled qACP which is a quantum generalization of process algebra ACP. But, an\naxiomatization for quantum and classical processes with an assumption of closed\nquantum systems is still missing. For closed quantum systems, unitary operator,\nquantum measurement and quantum entanglement are three basic components for\nquantum computing. This leads to probability unavoidable. Along the solution of\nqACP to unify quantum and classical computing in open quantum systems, we unify\nquantum and classical computing with an assumption of closed systems under the\nframework of ACP-like probabilistic process algebra. This unification make it\ncan be used widely in verification for quantum and classical computing mixed\nsystems, such as most quantum communication protocols.'}, 'authors': ['Yong Wang'], 'author_detail': {'name': 'Yong Wang'}, 'author': 'Yong Wang', 'arxiv_comment': '64 pages, 3 figures', 'links': [{'href': 'http://arxiv.org/abs/1610.02500v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1610.02500v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'cs.LO', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'cs.LO', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1610.02500v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1610.02500v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1402.1141v1', 'guidislink': True, 'updated': '2014-02-05T19:48:24Z', 'updated_parsed': time.struct_time(tm_year=2014, tm_mon=2, tm_mday=5, tm_hour=19, tm_min=48, tm_sec=24, tm_wday=2, tm_yday=36, tm_isdst=0), 'published': '2014-02-05T19:48:24Z', 'published_parsed': time.struct_time(tm_year=2014, tm_mon=2, tm_mday=5, tm_hour=19, tm_min=48, tm_sec=24, tm_wday=2, tm_yday=36, tm_isdst=0), 'title': 'Quantum Cybernetics and Complex Quantum Systems Science - A Quantum\n  Connectionist Exploration', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Cybernetics and Complex Quantum Systems Science - A Quantum\n  Connectionist Exploration'}, 'summary': "Quantum cybernetics and its connections to complex quantum systems science is\naddressed from the perspective of complex quantum computing systems. In this\nway, the notion of an autonomous quantum computing system is introduced in\nregards to quantum artificial intelligence, and applied to quantum artificial\nneural networks, considered as autonomous quantum computing systems, which\nleads to a quantum connectionist framework within quantum cybernetics for\ncomplex quantum computing systems. Several examples of quantum feedforward\nneural networks are addressed in regards to Boolean functions' computation,\nmultilayer quantum computation dynamics, entanglement and quantum\ncomplementarity. The examples provide a framework for a reflection on the role\nof quantum artificial neural networks as a general framework for addressing\ncomplex quantum systems that perform network-based quantum computation,\npossible consequences are drawn regarding quantum technologies, as well as\nfundamental research in complex quantum systems science and quantum biology.", 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': "Quantum cybernetics and its connections to complex quantum systems science is\naddressed from the perspective of complex quantum computing systems. In this\nway, the notion of an autonomous quantum computing system is introduced in\nregards to quantum artificial intelligence, and applied to quantum artificial\nneural networks, considered as autonomous quantum computing systems, which\nleads to a quantum connectionist framework within quantum cybernetics for\ncomplex quantum computing systems. Several examples of quantum feedforward\nneural networks are addressed in regards to Boolean functions' computation,\nmultilayer quantum computation dynamics, entanglement and quantum\ncomplementarity. The examples provide a framework for a reflection on the role\nof quantum artificial neural networks as a general framework for addressing\ncomplex quantum systems that perform network-based quantum computation,\npossible consequences are drawn regarding quantum technologies, as well as\nfundamental research in complex quantum systems science and quantum biology."}, 'authors': ['Carlos Pedro Gonçalves'], 'author_detail': {'name': 'Carlos Pedro Gonçalves'}, 'author': 'Carlos Pedro Gonçalves', 'links': [{'href': 'http://arxiv.org/abs/1402.1141v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1402.1141v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'cs.NE', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'cs.NE', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'cond-mat.dis-nn', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': '92B20, 81P68, 82C32', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1402.1141v1', 'a ...
# {'id': 'http://arxiv.org/abs/1210.0736v1', 'guidislink': True, 'updated': '2012-10-02T11:47:37Z', 'updated_parsed': time.struct_time(tm_year=2012, tm_mon=10, tm_mday=2, tm_hour=11, tm_min=47, tm_sec=37, tm_wday=1, tm_yday=276, tm_isdst=0), 'published': '2012-10-02T11:47:37Z', 'published_parsed': time.struct_time(tm_year=2012, tm_mon=10, tm_mday=2, tm_hour=11, tm_min=47, tm_sec=37, tm_wday=1, tm_yday=276, tm_isdst=0), 'title': 'Quantum Computation and Quantum Information', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Computation and Quantum Information'}, 'summary': 'Quantum computation and quantum information are of great current interest in\ncomputer science, mathematics, physical sciences and engineering. They will\nlikely lead to a new wave of technological innovations in communication,\ncomputation and cryptography. As the theory of quantum physics is fundamentally\nstochastic, randomness and uncertainty are deeply rooted in quantum\ncomputation, quantum simulation and quantum information. Consequently quantum\nalgorithms are random in nature, and quantum simulation utilizes Monte Carlo\ntechniques extensively. Thus statistics can play an important role in quantum\ncomputation and quantum simulation, which in turn offer great potential to\nrevolutionize computational statistics. While only pseudo-random numbers can be\ngenerated by classical computers, quantum computers are able to produce genuine\nrandom numbers; quantum computers can exponentially or quadratically speed up\nmedian evaluation, Monte Carlo integration and Markov chain simulation. This\npaper gives a brief review on quantum computation, quantum simulation and\nquantum information. We introduce the basic concepts of quantum computation and\nquantum simulation and present quantum algorithms that are known to be much\nfaster than the available classic algorithms. We provide a statistical\nframework for the analysis of quantum algorithms and quantum simulation.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum computation and quantum information are of great current interest in\ncomputer science, mathematics, physical sciences and engineering. They will\nlikely lead to a new wave of technological innovations in communication,\ncomputation and cryptography. As the theory of quantum physics is fundamentally\nstochastic, randomness and uncertainty are deeply rooted in quantum\ncomputation, quantum simulation and quantum information. Consequently quantum\nalgorithms are random in nature, and quantum simulation utilizes Monte Carlo\ntechniques extensively. Thus statistics can play an important role in quantum\ncomputation and quantum simulation, which in turn offer great potential to\nrevolutionize computational statistics. While only pseudo-random numbers can be\ngenerated by classical computers, quantum computers are able to produce genuine\nrandom numbers; quantum computers can exponentially or quadratically speed up\nmedian evaluation, Monte Carlo integration and Markov chain simulation. This\npaper gives a brief review on quantum computation, quantum simulation and\nquantum information. We introduce the basic concepts of quantum computation and\nquantum simulation and present quantum algorithms that are known to be much\nfaster than the available classic algorithms. We provide a statistical\nframework for the analysis of quantum algorithms and quantum simulation.'}, 'authors': ['Yazhen Wang'], 'author_detail': {'name': 'Yazhen Wang'}, 'author': 'Yazhen Wang', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1214/11-STS378', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/1210.0736v1', 'rel': 'alternate', ...
# {'id': 'http://arxiv.org/abs/q-alg/9509015v1', 'guidislink': True, 'updated': '1995-09-13T10:57:17Z', 'updated_parsed': time.struct_time(tm_year=1995, tm_mon=9, tm_mday=13, tm_hour=10, tm_min=57, tm_sec=17, tm_wday=2, tm_yday=256, tm_isdst=0), 'published': '1995-09-13T10:57:17Z', 'published_parsed': time.struct_time(tm_year=1995, tm_mon=9, tm_mday=13, tm_hour=10, tm_min=57, tm_sec=17, tm_wday=2, tm_yday=256, tm_isdst=0), 'title': 'Quantum Homogeneous Spaces as Quantum Quotient Spaces', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Homogeneous Spaces as Quantum Quotient Spaces'}, 'summary': 'We show that certain embeddable homogeneous spaces of a quantum group that do\nnot correspond to a quantum subgroup still have the structure of quantum\nquotient spaces. We propose a construction of quantum fibre bundles on such\nspaces. The quantum plane and the general quantum two-spheres are discussed in\ndetail.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We show that certain embeddable homogeneous spaces of a quantum group that do\nnot correspond to a quantum subgroup still have the structure of quantum\nquotient spaces. We propose a construction of quantum fibre bundles on such\nspaces. The quantum plane and the general quantum two-spheres are discussed in\ndetail.'}, 'authors': ['Tomasz Brzezinski'], 'author_detail': {'name': 'Tomasz Brzezinski'}, 'author': 'Tomasz Brzezinski', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1063/1.531517', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/q-alg/9509015v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/q-alg/9509015v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_comment': 'AmsTeX, 18pp', 'arxiv_primary_category': {'term': 'q-alg', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'q-alg', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'math.QA', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/q-alg/9509015v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/q-alg/9509015v1', 'journal_reference': None, 'doi': '10.1063/1.531517'}
# {'id': 'http://arxiv.org/abs/0907.3802v1', 'guidislink': True, 'updated': '2009-07-22T09:11:28Z', 'updated_parsed': time.struct_time(tm_year=2009, tm_mon=7, tm_mday=22, tm_hour=9, tm_min=11, tm_sec=28, tm_wday=2, tm_yday=203, tm_isdst=0), 'published': '2009-07-22T09:11:28Z', 'published_parsed': time.struct_time(tm_year=2009, tm_mon=7, tm_mday=22, tm_hour=9, tm_min=11, tm_sec=28, tm_wday=2, tm_yday=203, tm_isdst=0), 'title': 'Progress on Problem about Quantum Hamming Bound for Impure Quantum Codes', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Progress on Problem about Quantum Hamming Bound for Impure Quantum Codes'}, 'summary': 'A famous open problem in the theory of quantum error-correcting codes is\nwhether or not the parameters of an impure quantum code can violate the quantum\nHamming bound for pure quantum codes. We partially solve this problem. We\ndemonstrate that there exists a threshold such that an arbitrary quantum code\nmust obey the quantum Hamming bound whenever . We list some values of for small\nd and binary quantum codes.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'A famous open problem in the theory of quantum error-correcting codes is\nwhether or not the parameters of an impure quantum code can violate the quantum\nHamming bound for pure quantum codes. We partially solve this problem. We\ndemonstrate that there exists a threshold such that an arbitrary quantum code\nmust obey the quantum Hamming bound whenever . We list some values of for small\nd and binary quantum codes.'}, 'authors': ['Zhuo Li', 'Lijuan Xing'], 'author_detail': {'name': 'Lijuan Xing'}, 'author': 'Lijuan Xing', 'arxiv_comment': '3 pages, no figure', 'links': [{'href': 'http://arxiv.org/abs/0907.3802v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/0907.3802v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/0907.3802v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/0907.3802v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1509.06741v2', 'guidislink': True, 'updated': '2015-10-15T07:21:05Z', 'updated_parsed': time.struct_time(tm_year=2015, tm_mon=10, tm_mday=15, tm_hour=7, tm_min=21, tm_sec=5, tm_wday=3, tm_yday=288, tm_isdst=0), 'published': '2015-09-22T19:35:11Z', 'published_parsed': time.struct_time(tm_year=2015, tm_mon=9, tm_mday=22, tm_hour=19, tm_min=35, tm_sec=11, tm_wday=1, tm_yday=265, tm_isdst=0), 'title': 'Quantum variance: a measure of quantum coherence and quantum\n  correlations for many-body systems', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum variance: a measure of quantum coherence and quantum\n  correlations for many-body systems'}, 'summary': 'Quantum coherence is a fundamental common trait of quantum phenomena, from\nthe interference of matter waves to quantum degeneracy of identical particles.\nDespite its importance, estimating and measuring quantum coherence in generic,\nmixed many-body quantum states remains a formidable challenge, with fundamental\nimplications in areas as broad as quantum condensed matter, quantum\ninformation, quantum metrology and quantum biology. Here we provide a\nquantitative definition of the variance of quantum coherent fluctuations (the\nquantum variance) of any observable on generic quantum states. The quantum\nvariance generalizes the concept of thermal de Broglie wavelength (for the\nposition of a free quantum particle) to the space of eigenvalues of any\nobservable, quantifying the degree of coherent delocalization in that space.\nThe quantum variance is generically measurable and computable as the difference\nbetween the static fluctuations and the static susceptibility of the\nobservable; despite its simplicity, it is found to provide a tight lower bound\nto most widely accepted estimators of "quantumness" of observables (both as a\nfeature as well as a resource), such as the Wigner-Yanase skew information and\nthe quantum Fisher information. When considering bipartite fluctuations in an\nextended quantum system, the quantum variance expresses genuine quantum\ncorrelations (of discord type) among the two parts. In the case of many-body\nsystems it is found to obey an area law at finite temperature, extending\ntherefore area laws of entanglement and quantum fluctuations of pure states to\nthe mixed-state context. Hence the quantum variance paves the way to the\nmeasurement of macroscopic quantum coherence and quantum correlations in most\ncomplex quantum systems.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum coherence is a fundamental common trait of quantum phenomena, from\nthe interference of matter waves to quantum degeneracy of identical particles.\nDespite its importance, estimating and measuring quantum coherence in generic,\nmixed many-body quantum states remains a formidable challenge, with fundamental\nimplications in areas as broad as quantum condensed matter, quantum\ninformation, quantum metrology and quantum biology. Here we provide a\nquantitative definition of the variance of quantum coherent fluctuations (the\nquantum variance) of any observable on generic quantum states. The quantum\nvariance generalizes the concept of thermal de Broglie wavelength (for the\nposition of a free quantum particle) to the space of eigenvalues of any\nobservable, quantifying the degree of coherent delocalization in that space.\nThe quantum variance is generically measurable and computable as the difference\nbetween the static fluctuations and the static susceptibility of the\nobservable; despite its simplicity, it is found to provide a tight lower bound\nto most widely accepted estimators of "quantumness" of observables (both as a\nfe ...
# {'id': 'http://arxiv.org/abs/0804.0180v2', 'guidislink': True, 'updated': '2008-10-22T13:41:45Z', 'updated_parsed': time.struct_time(tm_year=2008, tm_mon=10, tm_mday=22, tm_hour=13, tm_min=41, tm_sec=45, tm_wday=2, tm_yday=296, tm_isdst=0), 'published': '2008-04-01T13:59:55Z', 'published_parsed': time.struct_time(tm_year=2008, tm_mon=4, tm_mday=1, tm_hour=13, tm_min=59, tm_sec=55, tm_wday=1, tm_yday=92, tm_isdst=0), 'title': 'Transforming quantum operations: quantum supermaps', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Transforming quantum operations: quantum supermaps'}, 'summary': 'We introduce the concept of quantum supermap, describing the most general\ntransformation that maps an input quantum operation into an output quantum\noperation. Since quantum operations include as special cases quantum states,\neffects, and measurements, quantum supermaps describe all possible\ntransformations between elementary quantum objects (quantum systems as well as\nquantum devices). After giving the axiomatic definition of supermap, we prove a\nrealization theorem, which shows that any supermap can be physically\nimplemented as a simple quantum circuit. Applications to quantum programming,\ncloning, discrimination, estimation, information-disturbance trade-off, and\ntomography of channels are outlined.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=10&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We introduce the concept of quantum supermap, describing the most general\ntransformation that maps an input quantum operation into an output quantum\noperation. Since quantum operations include as special cases quantum states,\neffects, and measurements, quantum supermaps describe all possible\ntransformations between elementary quantum objects (quantum systems as well as\nquantum devices). After giving the axiomatic definition of supermap, we prove a\nrealization theorem, which shows that any supermap can be physically\nimplemented as a simple quantum circuit. Applications to quantum programming,\ncloning, discrimination, estimation, information-disturbance trade-off, and\ntomography of channels are outlined.'}, 'authors': ['G. Chiribella', "G. M. D'Ariano", 'P. Perinotti'], 'author_detail': {'name': 'P. Perinotti'}, 'author': 'P. Perinotti', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1209/0295-5075/83/30004', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/0804.0180v2', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/0804.0180v2', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_comment': '6 pages, 1 figure, published version', 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/0804.0180v2', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/0804.0180v2', 'journal_reference': 'Europhysics Letters 83, 30004 (2008)', 'doi': '10.1209/0295-5075/83/30004'}
# ...
# {'id': 'http://arxiv.org/abs/quant-ph/0407030v1', 'guidislink': True, 'updated': '2004-07-05T08:43:07Z', 'updated_parsed': time.struct_time(tm_year=2004, tm_mon=7, tm_mday=5, tm_hour=8, tm_min=43, tm_sec=7, tm_wday=0, tm_yday=187, tm_isdst=0), 'published': '2004-07-05T08:43:07Z', 'published_parsed': time.struct_time(tm_year=2004, tm_mon=7, tm_mday=5, tm_hour=8, tm_min=43, tm_sec=7, tm_wday=0, tm_yday=187, tm_isdst=0), 'title': 'Quantum State of Entangled Photon Pairs', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum State of Entangled Photon Pairs'}, 'summary': "I show that the photon pairs used in experimental tests of quantum\nnon-locality based on Bell's theorem are not in the entangled quantum state.\nThe correct quantum state of the ``entangled'' photon pairs is suggested. Two\nexperiments for testing this quantum state are proposed.", 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': "I show that the photon pairs used in experimental tests of quantum\nnon-locality based on Bell's theorem are not in the entangled quantum state.\nThe correct quantum state of the ``entangled'' photon pairs is suggested. Two\nexperiments for testing this quantum state are proposed."}, 'authors': ['Ruo Peng Wang'], 'author_detail': {'name': 'Ruo Peng Wang'}, 'author': 'Ruo Peng Wang', 'arxiv_comment': '3 figures', 'links': [{'href': 'http://arxiv.org/abs/quant-ph/0407030v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0407030v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0407030v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0407030v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/quant-ph/0412048v1', 'guidislink': True, 'updated': '2004-12-06T21:56:54Z', 'updated_parsed': time.struct_time(tm_year=2004, tm_mon=12, tm_mday=6, tm_hour=21, tm_min=56, tm_sec=54, tm_wday=0, tm_yday=341, tm_isdst=0), 'published': '2004-12-06T21:56:54Z', 'published_parsed': time.struct_time(tm_year=2004, tm_mon=12, tm_mday=6, tm_hour=21, tm_min=56, tm_sec=54, tm_wday=0, tm_yday=341, tm_isdst=0), 'title': 'A quantum cellular automaton for universal quantum computation', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'A quantum cellular automaton for universal quantum computation'}, 'summary': "I describe a quantum cellular automaton capable of performing universal\nquantum computation. The automaton has an elementary transition function that\nacts on Margolus cells of $2\\times 2$ qubits, and both the ``quantum input''\nand the program are encoded in the initial state of the system.", 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': "I describe a quantum cellular automaton capable of performing universal\nquantum computation. The automaton has an elementary transition function that\nacts on Margolus cells of $2\\times 2$ qubits, and both the ``quantum input''\nand the program are encoded in the initial state of the system."}, 'authors': ['Robert Raussendorf'], 'author_detail': {'name': 'Robert Raussendorf'}, 'author': 'Robert Raussendorf', 'links': [{'title': 'doi', 'href': 'http://dx.doi.org/10.1103/PhysRevA.72.022301', 'rel': 'related', 'type': 'text/html'}, {'href': 'http://arxiv.org/abs/quant-ph/0412048v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/quant-ph/0412048v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_comment': '4 pages, 3 figures', 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/quant-ph/0412048v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/quant-ph/0412048v1', 'journal_reference': None, 'doi': '10.1103/PhysRevA.72.022301'}
# {'id': 'http://arxiv.org/abs/0908.2118v1', 'guidislink': True, 'updated': '2009-08-14T19:00:51Z', 'updated_parsed': time.struct_time(tm_year=2009, tm_mon=8, tm_mday=14, tm_hour=19, tm_min=0, tm_sec=51, tm_wday=4, tm_yday=226, tm_isdst=0), 'published': '2009-08-14T19:00:51Z', 'published_parsed': time.struct_time(tm_year=2009, tm_mon=8, tm_mday=14, tm_hour=19, tm_min=0, tm_sec=51, tm_wday=4, tm_yday=226, tm_isdst=0), 'title': 'Quantum vertex $C((t))$-algebras and quantum affine algebras', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum vertex $C((t))$-algebras and quantum affine algebras'}, 'summary': 'We give a summary of the theory of (weak) quantum vertex $\\C((t))$-algebras\nand the association of quantum affine algebras with (weak) quantum vertex\n$\\C((t))$-algebras.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We give a summary of the theory of (weak) quantum vertex $\\C((t))$-algebras\nand the association of quantum affine algebras with (weak) quantum vertex\n$\\C((t))$-algebras.'}, 'authors': ['Haisheng Li'], 'author_detail': {'name': 'Haisheng Li'}, 'author': 'Haisheng Li', 'arxiv_comment': '14 pages, in the proceedings of the international conference "Finite\n  Groups, Vertex Operator Algebras and Combinatorics," RIMS, January, 2009', 'links': [{'href': 'http://arxiv.org/abs/0908.2118v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/0908.2118v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'math.QA', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'math.QA', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': '17B69', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/0908.2118v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/0908.2118v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1511.05006v2', 'guidislink': True, 'updated': '2019-06-02T13:41:47Z', 'updated_parsed': time.struct_time(tm_year=2019, tm_mon=6, tm_mday=2, tm_hour=13, tm_min=41, tm_sec=47, tm_wday=6, tm_yday=153, tm_isdst=0), 'published': '2015-11-16T15:56:21Z', 'published_parsed': time.struct_time(tm_year=2015, tm_mon=11, tm_mday=16, tm_hour=15, tm_min=56, tm_sec=21, tm_wday=0, tm_yday=320, tm_isdst=0), 'title': 'Quantum Coding Theorems', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum Coding Theorems'}, 'summary': 'We prove the quantum analogy of the coding theorem for both pure quantum\nstates and mixed quantum states. The quantum coding theorems have applications\nin relating different quantum algorithmic entropy measures.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'We prove the quantum analogy of the coding theorem for both pure quantum\nstates and mixed quantum states. The quantum coding theorems have applications\nin relating different quantum algorithmic entropy measures.'}, 'authors': ['Samuel Epstein'], 'author_detail': {'name': 'Samuel Epstein'}, 'author': 'Samuel Epstein', 'arxiv_comment': '18 pages, 4 figures', 'links': [{'href': 'http://arxiv.org/abs/1511.05006v2', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1511.05006v2', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'cs.CC', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'cs.CC', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1511.05006v2', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1511.05006v2', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1108.3445v1', 'guidislink': True, 'updated': '2011-08-17T11:13:51Z', 'updated_parsed': time.struct_time(tm_year=2011, tm_mon=8, tm_mday=17, tm_hour=11, tm_min=13, tm_sec=51, tm_wday=2, tm_yday=229, tm_isdst=0), 'published': '2011-08-17T11:13:51Z', 'published_parsed': time.struct_time(tm_year=2011, tm_mon=8, tm_mday=17, tm_hour=11, tm_min=13, tm_sec=51, tm_wday=2, tm_yday=229, tm_isdst=0), 'title': 'Quantum computer for dummies (in Russian)', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum computer for dummies (in Russian)'}, 'summary': 'An introduction (in Russian) to quantum computers, quantum cryptography, and\nquantum teleportation for students who have no previous knowledge of these\nsubjects, but know quantum mechanics. Several simple examples are considered in\ndetail using the quantum computer emulator QCL.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'An introduction (in Russian) to quantum computers, quantum cryptography, and\nquantum teleportation for students who have no previous knowledge of these\nsubjects, but know quantum mechanics. Several simple examples are considered in\ndetail using the quantum computer emulator QCL.'}, 'authors': ['Andrey Grozin'], 'author_detail': {'name': 'Andrey Grozin'}, 'author': 'Andrey Grozin', 'arxiv_comment': '24 small (A5) pages', 'links': [{'href': 'http://arxiv.org/abs/1108.3445v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1108.3445v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'physics.pop-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'physics.pop-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1108.3445v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1108.3445v1', 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1301.3407v1', 'guidislink': True, 'updated': '2013-01-15T16:35:13Z', 'updated_parsed': time.struct_time(tm_year=2013, tm_mon=1, tm_mday=15, tm_hour=16, tm_min=35, tm_sec=13, tm_wday=1, tm_yday=15, tm_isdst=0), 'published': '2013-01-15T16:35:13Z', 'published_parsed': time.struct_time(tm_year=2013, tm_mon=1, tm_mday=15, tm_hour=16, tm_min=35, tm_sec=13, tm_wday=1, tm_yday=15, tm_isdst=0), 'title': 'Commuting Local Hamiltonians on Expanders, Locally Testable Quantum\n  codes, and the qPCP conjecture', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Commuting Local Hamiltonians on Expanders, Locally Testable Quantum\n  codes, and the qPCP conjecture'}, 'summary': 'Understanding commuting local Hamiltonians (CLHs) is at the heart of many\nquestions in quantum computational complexity and quantum physics: quantum\nerror correcting codes, quantum NP, the PCP conjecture, topological order and\nmore.', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Understanding commuting local Hamiltonians (CLHs) is at the heart of many\nquestions in quantum computational complexity and quantum physics: quantum\nerror correcting codes, quantum NP, the PCP conjecture, topological order and\nmore.'}, 'authors': ['Dorit Aharonov', 'Lior Eldar'], 'author_detail': {'name': 'Lior Eldar'}, 'author': 'Lior Eldar', 'links': [{'href': 'http://arxiv.org/abs/1301.3407v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1301.3407v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1301.3407v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1301.3407v1', 'arxiv_comment': None, 'journal_reference': None, 'doi': None}
# {'id': 'http://arxiv.org/abs/1408.2836v1', 'guidislink': True, 'updated': '2014-08-12T20:07:47Z', 'updated_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=12, tm_hour=20, tm_min=7, tm_sec=47, tm_wday=1, tm_yday=224, tm_isdst=0), 'published': '2014-08-12T20:07:47Z', 'published_parsed': time.struct_time(tm_year=2014, tm_mon=8, tm_mday=12, tm_hour=20, tm_min=7, tm_sec=47, tm_wday=1, tm_yday=224, tm_isdst=0), 'title': 'Quantum interview', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'Quantum interview'}, 'summary': 'This paper collects into one place my replies to the questions posed by\nMaximilian Schlosshauer in his interview volume about the foundations of\nquantum mechanics, "Elegance and Enigma: The Quantum Interviews" (Springer,\n2011).', 'summary_detail': {'type': 'text/plain', 'language': None, 'base': 'http://export.arxiv.org/api/query?search_query=quantum&id_list=&start=90&max_results=10&sortBy=relevance&sortOrder=descending', 'value': 'This paper collects into one place my replies to the questions posed by\nMaximilian Schlosshauer in his interview volume about the foundations of\nquantum mechanics, "Elegance and Enigma: The Quantum Interviews" (Springer,\n2011).'}, 'authors': ['Antony Valentini'], 'author_detail': {'name': 'Antony Valentini'}, 'author': 'Antony Valentini', 'arxiv_comment': '21 pages, "Elegance and Enigma: The Quantum Interviews", ed. M.\n  Schlosshauer (Springer, 2011)', 'links': [{'href': 'http://arxiv.org/abs/1408.2836v1', 'rel': 'alternate', 'type': 'text/html'}, {'title': 'pdf', 'href': 'http://arxiv.org/pdf/1408.2836v1', 'rel': 'related', 'type': 'application/pdf'}], 'arxiv_primary_category': {'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom'}, 'tags': [{'term': 'quant-ph', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'gr-qc', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}, {'term': 'hep-th', 'scheme': 'http://arxiv.org/schemas/atom', 'label': None}], 'pdf_url': 'http://arxiv.org/pdf/1408.2836v1', 'affiliation': 'None', 'arxiv_url': 'http://arxiv.org/abs/1408.2836v1', 'journal_reference': None, 'doi': None}
